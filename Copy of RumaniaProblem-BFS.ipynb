# %%
precios={'pan':500,'Azucar':1500,'Sal':750,'panela':1500}
query=precios['pan']
print(query)
for key, value in precios.items():
  print(key, value)
precios['chocolate']=3500
print(precios)
print(list(precios.keys()))
print(list(precios.values()))
# Out:
# 500
# pan 500
# Azucar 1500
# Sal 750
# panela 1500
# {'pan': 500, 'Azucar': 1500, 'Sal': 750, 'panela': 1500, 'chocolate': 3500}
# ['pan', 'Azucar', 'Sal', 'panela', 'chocolate']
# [500, 1500, 750, 1500, 3500]

# %%
class Vertex:
    def __init__(self,key):
        self.id = key
        self.connectedTo = {}

    def addNeighbor(self,nbr,weight=0):
        self.connectedTo[nbr] = weight

    def __str__(self):
        return str(self.id) + ' connectedTo: ' + str([x.id for x in self.connectedTo])

    def getConnections(self):
        return self.connectedTo.keys()

    def getId(self):
        return self.id

    def getWeight(self,nbr):
        return self.connectedTo[nbr]

# %%
class Graph:
    def __init__(self):
        self.vertList = {}
        self.numVertices = 0

    def addVertex(self,key):
        self.numVertices = self.numVertices + 1
        newVertex = Vertex(key)
        self.vertList[key] = newVertex
        return newVertex

    def getVertex(self,n):
        if n in self.vertList:
            return self.vertList[n]
        else:
            return None

    def __contains__(self,n):
        return n in self.vertList

    def addEdge(self,f,t,weight=0):
        if f not in self.vertList:
            nv = self.addVertex(f)
        if t not in self.vertList:
            nv = self.addVertex(t)
        self.vertList[f].addNeighbor(self.vertList[t], weight)

    def getVertices(self):
        return self.vertList.keys()

    def __iter__(self):
        return iter(self.vertList.values())

# %%
cities = ['Arad','Bucharest','Craiova','Dobreta','Eforie','Fagaras','Giurgiu','Hirsova','Iasi','Lugoj','Mehadia','Neamt','Oradea','Pitesti','Rimnicu Vilcea','Sibiu','Timisoara','Urziceni','Vaslui','Zerind']

graph = Graph()

for city in cities:
  graph.addVertex(city)
graph.addEdge('Arad','Timisoara',118)
graph.addEdge('Arad','Zerind',75)
graph.addEdge('Arad','Sibiu',140)

graph.addEdge('Timisoara','Arad',118)
graph.addEdge('Timisoara','Lugoj',111)

graph.addEdge('Lugoj','Timisora',111)
graph.addEdge('Lugoj','Mehadia',70)

graph.addEdge('Mehadia','Lugoj',70)
graph.addEdge('Mehadia','Dobreta',75)

graph.addEdge('Dobreta','Mehadia',75)
graph.addEdge('Dobreta','Craiova',120)

graph.addEdge('Craiova','Dobreta',120)
graph.addEdge('Craiova','Rimnicu Vilcea',146)
graph.addEdge('Craiova','Pitesti',138)

graph.addEdge('Rimnicu Vilcea','Craiova',146)
graph.addEdge('Rimnicu Vilcea','Sibiu',80)
graph.addEdge('Rimnicu Vilcea','Pitesti',97)

graph.addEdge('Sibiu','Rimnicu Vilcea',80)
graph.addEdge('Sibiu','Faragas',99)
graph.addEdge('Sibiu','Oradea',151)
graph.addEdge('Sibiu','Arad',140)

graph.addEdge('Oradea','Sibiu',151)
graph.addEdge('Oradea','Zerind',71)

graph.addEdge('Zerind','Oradea',71)
graph.addEdge('Zerind','Arad',75)

graph.addEdge('Faragas','Sibiu',99)
graph.addEdge('Faragas','Bucharest',211)

graph.addEdge('Bucharest','Faragas',211)
graph.addEdge('Bucharest','Pitesti',101)
graph.addEdge('Bucharest','Giurgiu',90)
graph.addEdge('Bucharest','Urziceni',85)

graph.addEdge('Pitesti','Bucharest',101)
graph.addEdge('Pitesti','Rimnicu Vilcea',97)
graph.addEdge('Pitesti','Craiova',138)

graph.addEdge('Giurgiu','Bucharest',90)

graph.addEdge('Urziceni','Bucharest',85)
graph.addEdge('Urziceni','Vaslui',142)
graph.addEdge('Urziceni','Hirsova',98)

graph.addEdge('Hirsova','Urziceni',98)
graph.addEdge('Hirsova','Eforie',86)

graph.addEdge('Eforie','Hirsova',86)

graph.addEdge('Vaslui','Urziceni',142)
graph.addEdge('Vaslui','Iasi',92)

graph.addEdge('Iasi','Vaslui',92)
graph.addEdge('Iasi','Neamt',87)

graph.addEdge('Neamt','Iasi',87)

vtx=graph.getVertex('Pitesti')
cnx=vtx.getConnections()
cnx=[vert.id for vert in cnx]
print(cnx)

vtx1=graph.getVertex('Pitesti')
vtx2=graph.getVertex('Bucharest')
c=vtx1.getWeight(vtx2)
print(c)
# Out:
# ['Bucharest', 'Rimnicu Vilcea', 'Craiova']
# 101

# %%
class Node:
    def __init__(self, state, parent=None, action=None, path_cost=0):
        self.state = state
        self.parent = parent
        self.action = action
        self.path_cost = path_cost
        self.depth = 0
        if parent:
            self.depth = parent.depth + 1

    def __repr__(self):
        rep = 'Node(' + str(self.state)+')\n'
        return rep
    def __eq__(self, node):
        return self.state == node.state

# %%
class Problem(object):
  
  def __init__(self, initial, goal):
    
    if not isinstance(initial,Node):
      raise TypeError('node type is required for initial')
    if not isinstance(goal,Node):
      raise TypeError('node type is required for initial')

    self.initial = initial
    self.goal = goal
    
  def expand(self, node):
    
    raise NotImplementedError

# %%
class BreadthFirstSearch:
  def __init__(self, problem):
    self.open=[]
    self.close=[]
    self.children=[]
    self.problem=problem

  def run(self):
    self.open.append(self.problem.initial)
    solution=[]
    while self.open :
      actual=self.open.pop(0)
      print('actual',actual)
      if(actual == self.problem.goal):
        while actual:
          action=actual.action
          actual=actual.parent
          solution.append(action)
        solution.reverse()
        return solution

      else:
        self.close.append(actual)
        self.children=self.problem.expand(actual)
        self.clean()
        self.open.extend(self.children)
    return solution

  def clean(self):
    for n in self.children[:]:
      for m in self.open:
        if(n==m):
          self.children.remove(n)
    for n in self.children[:]:
      for m in self.close:
        if(n==m):
          self.children.remove(n)

# %%
class Dijkstra:
  def __init__(self, problem):
    self.open=[]
    self.close=[]
    self.children=[]
    self.problem=problem

  def run(self):
    self.open.append(self.problem.initial)
    solution=[]
    while self.open :
      actual=self.open.pop(0)
      print('actual',actual)
      if(actual == self.problem.goal):
        while actual:
          action=actual.action
          actual=actual.parent
          solution.append(action)
        solution.reverse()
        return solution

      else:
        self.close.append(actual)
        self.children=self.problem.expand(actual)
        self.clean()
        self.open.extend(self.children)
        self.sortList(self.open)
        #print('lista abierto',self.open)
        
        #self.open.sort()
    return solution
  def sortList(self,lista):
    pos=0
    i=0
    aux=0
    for _ in lista:
      pos = i
      while pos>0 and lista[pos-1] > aux:
        lista[pos] = lista[pos-1]
        pos=pos-1
      lista[pos] = aux
      i = i+1
    return lista
  def clean(self):
    for n in self.children[:]:
      for m in self.open:
        if(n==m):
          self.children.remove(n)
    for n in self.children[:]:
      for m in self.close:
        if(n==m):
          self.children.remove(n)

# %%
class Travel(Problem):
  def __init__(self, graph, initial, goal):
    Problem.__init__(self, initial, goal)
    self.graph=graph

  def expand(self, node):
    children=[]
    state=node.state
    vtx=self.graph.getVertex(state)
    cnx=vtx.getConnections()
    cnx=[vert.id for vert in cnx]
    for city in cnx:
      accion='Viajar('+ state + ',' + city+')'
      vtx1=self.graph.getVertex(state)
      vtx2=self.graph.getVertex(city)
      c=vtx1.getWeight(vtx2)
      costo=node.path_cost+c
      node = Node(city, node, accion, costo)
      children.append(node)
    return children

# %%
def main():
    initial=Node('Arad')
    goal=Node('Bucharest')

    travel=Travel(graph,initial, goal)
    bfs=BreadthFirstSearch(travel)
    #fms= Dijkstra(travel)

    solution=bfs.run()
    print(solution)
    

if __name__ == "__main__":
    main()
# Out:
# actual Node(Arad)
#
# actual Node(Timisoara)
#
# actual Node(Zerind)
#
# actual Node(Sibiu)
#
# actual Node(Lugoj)
#
# actual Node(Oradea)
#
# actual Node(Rimnicu Vilcea)
#
# actual Node(Faragas)
#
# actual Node(Timisora)
#
# actual Node(Mehadia)
#
# actual Node(Craiova)
#
# actual Node(Pitesti)
#
# actual Node(Bucharest)
#
# [None, 'Viajar(Arad,Timisoara)', 'Viajar(Arad,Zerind)', 'Viajar(Arad,Sibiu)', 'Viajar(Sibiu,Rimnicu Vilcea)', 'Viajar(Sibiu,Faragas)', 'Viajar(Faragas,Sibiu)', 'Viajar(Faragas,Bucharest)']
